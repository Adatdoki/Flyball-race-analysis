# %%
#240511

# %% [markdown]
# # Tóth Zoltán (junior kategória) 2024.05.12.

# %% [markdown]
# ## 1. HÁZI DATA SCIENCE VERSENY
#
# Flyball* csapat (Wild Runners Flyball Team – innentől csak WRFT) edzője felkereste a Data Science Klubot, hogy megtalálja azt a legrátermettebb elemzőt, aki segítene számára feldolgozni a csapata 2023-as verseny eredményeit. A cél, hogy az elemzéseket felhasználva a jövőben még jobb teljesítményt nyújthasson a csapat.

# %% [markdown]
# ![Flyball.png](data:image/png;base64,...)

# %% [markdown]
# ####Forrás: AI generált kép

# %% [markdown]
# # Ebben a sorrendben következnek egymás után az adatfeldolgozások:

# %% [markdown]
# ##Wild_Runners_Flyball_Team_kutyak_alapadatai.xlsx feldolgozása

# %% [markdown]
# 1.   Futtasd először ezt a fájlt: Flyball_WRFT_cleaning_XXXXXX.ipynb
# 2.   Ezt a bemenetet várja: Wild_Runners_Flyball_Team_kutyak_alapadatai.xlsx
# 3.   Belső dataframe: df_WRFT
# 4.   Ez lesz a kimenete: df_WRFT_output.csv

# %% [markdown]
# ##EFC_versenyadatok.xlsx feldolgozása

# %% [markdown]
# 1.   Futtasd először ezt a fájlt:    Flyball_EFC_cleaning_XXXXXX.ipynb
# 2.   Ezt a bemenetet várja:          EFC_versenyadatok.xlsx
# 3.   Belső dataframe: df_EFC
# 4.   Ez lesz a kimenete: df_EFC_output.csv

# %% [markdown]
# ##FLYBALLCZ_versenyadatok.xlsx feldolgozása

# %% [markdown]
# 1.   Futtasd először ezt a fájlt:    Flyball_CZ_cleaning_XXXXXX.ipynb
# 2.   Ezt a bemenetet várja:          FLYBALLCZ_versenyadatok.xlsx
# 3.   Belső dataframe: df_CZ
# 4.   Ez lesz a kimenete: df_CZ_output.csv

# %% [markdown]
# ##FLYBALL EFC és CZ_versenyadatok egyesítése, feldolgozása

# %% [markdown]
# 1.   Futtasd először ezt a fájlt: Flyball_EFC_CZ_merging_analyzing_XXXXXX.ipynb
# 2.   Ezt a bemenetet várja: df_EFC_output.csv és df_CZ_output.csv
# 3.   Belső dataframe:  df_EFC_CZ -> df_EFC_CZ_track
# 4.   Ez lesz a kimenete: df_EFC_CZ_track_good-date.csv

# %% [markdown]
# ##Flyball_EFC_CZ_post_analyzing, versenyadatok továbbfeldolgozása

# %% [markdown]
# 1.   Futtasd először ezt a fájlt: Flyball_EFC_CZ_post_analyzing_XXXXXX.ipynb
# 2.   Ezt a bemenetet várja: df_EFC_CZ_track_good-date.csv
# 3.   Belső dataframe:  df_EFC_CZ_merged
# 4.   Ez lesz a kimenete: df_EFC_CZ_post_analyzing_merged.csv

# %% [markdown]
# ## Flyball_EFC_CZ_weatherAPI, azaz időjárás adatok hozzáadása

# %% [markdown]
# 1.   Futtasd először ezt a fájlt: Flyball_EFC_CZ_weatherAPI_XXXXXX.ipynb
# 2.   Ezt a bemenetet várja: df_EFC_CZ_post_analyzing_merged.csv
# 3.   Belső dataframe:  df_EFC_CZ_Weather
# 4.   Ez lesz a kimenete: df_EFC_CZ_Weather.csv

# %% [markdown]
# ###Sajnos a rendelkezésemre álló idő hiányában nincs folytatás, pedig az elképzeléseim még nem fogytak el. Sőt most lódultak meg igazán. De ezt már csak versenyen kívül folytatom majd.

# %% [markdown]
# # Mindenesetre nagyon köszönöm a verseny és az adathalmaz megvalósítóinak, hogy már így is rengeteget tanultam, a gyakorlati adatelemzés megközelítés buktatóinak megtapasztalásában.
# ##Sikerült egy mindenre kiterjedő, kellően "piszkos' adathalmazt kreálni. Az elsőre átláthatatlan adathalmazok, a megismerés közben szép lassan átláthatóvá váltak.
# #Köszönöm ezt a "gyötrelmes" de igen hasznos utazást a cél felé! -TZ-
